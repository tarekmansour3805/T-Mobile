# %%
import requests 
from requests.auth import HTTPDigestAuth
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pyodbc 
db = pyodbc.connect('Driver={SQL Server};'
                      'Server=PGI-M2M;'
                      'Database=M2MDATA25;'
                      'Trusted_Connection=yes;')



query = 'select fpartno, fpartrev, flot, fonhand, flocation  from dbo.inonhd'
v = pd.read_sql_query(query , db)
v['fpartno'] = v['fpartno'].str.replace(' ', '')
v['flot'] = v['flot'].str.replace(' ', '')
v['fonhand'] = v['fonhand'].replace(' ', '')
v['fpartrev'] = v['fpartrev'].replace(' ', '')
v['flocation'] = v['flocation'].replace(' ', '')

v.replace('', np.nan, inplace=True)
v.applymap(lambda x: x.rstrip() if type(x)==str else x)
v = v[pd.notnull(v['flot'])]
v = v.drop_duplicates('flot',keep = 'first')

# %%
r = requests.get('http://188.95.79.97:8081/?f=login&username=PRECISION&password=PRECISION')

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><resp f="login" apiver="2.15" err="0" errdesc="done"><out><token>851882724653</token></out><resdetail>warning: user was already logged</resdetail></resp>'

# %%
token = '851882724653'

# %%
r = requests.get(f'http://188.95.79.97:8081/?f=item_getlist&tkn={token}')

# %%
partno = '21160'
lot = 'JUKI'
qty = '40'

# %%
r = requests.post(f'http://188.95.79.97:8081/?f=reel_setquantity&reel_code={lot}&quantity={qty}&tkn={token}')

# %%
r.text
# Out:
# '<?xml version="1.0" encoding="utf-8" ?><resp f="reel_setquantity" apiver="2.15" err="30" errdesc="notfound"><resdetail>reel not found</resdetail></resp>'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'lxml')

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <html>
#  <body>
#   <resp apiver="2.15" err="0" errdesc="done" f="item_getlist" lastfound="61" totfound="62">
#    <out>
#     <itemlist>
#      <iteminfo>
#       <id>
#        1
#       </id>
#       <code>
#        TEST ITEM
#       </code>
#       <description>
#        EFM TEST
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        2
#       </id>
#       <code>
#        TEST2
#       </code>
#       <description>
#        EFM TEST
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        3
#       </id>
#       <code>
#        RYT1136714/2
#       </code>
#       <description>
#        ERICSSON PART
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        4
#       </id>
#       <code>
#        P0006
#       </code>
#       <description>
#        M1
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        5
#       </id>
#       <code>
#        PART_A
#       </code>
#       <description>
#        NONE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        6072000
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        6
#       </id>
#       <code>
#        PART_C
#       </code>
#       <description>
#        NONE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        510000
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        7
#       </id>
#       <code>
#        PART_B
#       </code>
#       <description>
#        NONE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        1500000
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        8
#       </id>
#       <code>
#        TESTALTEA
#       </code>
#       <description>
#        TEST ARTICOLO ALTEA
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        9
#       </id>
#       <code>
#        2317854
#       </code>
#       <description>
#        754621
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        10
#       </id>
#       <code>
#        833554A
#       </code>
#       <description>
#        NONE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        11
#       </id>
#       <code>
#        TESTQUOTE
#       </code>
#       <description>
#        PROVA DECODIFICA VIRGOLETTE VIA API "
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        12
#       </id>
#       <code>
#        ART000100
#       </code>
#       <description>
#        SOFTWARE FIREWALL
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        13
#       </id>
#       <code>
#        WSV
#       </code>
#       <description>
#        GUANTI BIANCHI
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        14
#       </id>
#       <code>
#        WSV00020
#       </code>
#       <description>
#        CARTA OPTIMA PRIMA SCELTA
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        15
#       </id>
#       <code>
#        IFP2102010
#       </code>
#       <description>
#        IFP KIT BASE PC
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        16
#       </id>
#       <code>
#        IFP2100430
#       </code>
#       <description>
#        IFP KIT P4 2.7
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        25000
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        17
#       </id>
#       <code>
#        IFP3100010
#       </code>
#       <description>
#        IFP TASTIERA
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        18
#       </id>
#       <code>
#        IFP3100020
#       </code>
#       <description>
#        IFP MOUSE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        19
#       </id>
#       <code>
#        IFP3303020
#       </code>
#       <description>
#        IFP ETICHETTA X CARTONE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        21
#       </id>
#       <code>
#        ART00100
#       </code>
#       <description>
#        SOFTWARE FIREWALL ROSSO e blu
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        34
#       </id>
#       <code>
#        11630-00400
#       </code>
#       <description>
#        MATTONCINO LEGA PREFORM. 0402
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        35
#       </id>
#       <code>
#        24120-00900
#       </code>
#       <description>
#        ETICHETTA "PA" HIGH TEMP 5X5MM. BI
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        36
#       </id>
#       <code>
#        32640-11421
#       </code>
#       <description>
#        C.S. FRONTALE LED HI! CHIAVE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        37
#       </id>
#       <code>
#        32240S00420
#       </code>
#       <description>
#        CONN.M.DIR.CS (P.2,54) 4 VIE (2X2)
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        38
#       </id>
#       <code>
#        36006S10910
#       </code>
#       <description>
#        CIRC.INT. 74LVC1G14GW SMD
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        39
#       </id>
#       <code>
#        36006S10850
#       </code>
#       <description>
#        CIRC.INT. SINGLE G. SMD 74AHC1G125
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        40
#       </id>
#       <code>
#        36006S11210
#       </code>
#       <description>
#        CIRC.INT. SINGLE GATE 74HCT1G126GW
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        41
#       </id>
#       <code>
#        36016S60400
#       </code>
#       <description>
#        CIRC.INT. TLV70233  3V3 WSON (DSE)
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        42
#       </id>
#       <code>
#        36200S10101
#       </code>
#       <description>
#        DIODO SMD 1N4148WS SOD-323
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        43
#       </id>
#       <code>
#        36209S10100
#       </code>
#       <description>
#        DIODO TRIPLO NEXPERIA  BAS16V-V
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        44
#       </id>
#       <code>
#        36220S10220
#       </code>
#       <description>
#        TRANS. PNP BC807-25
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        1200000
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        45
#       </id>
#       <code>
#        36220S90400
#       </code>
#       <description>
#        TRANS. NPN NPN NXP PEMH10
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        46
#       </id>
#       <code>
#        36263S60200
#       </code>
#       <description>
#        CIRC.INT. TFDU4101-TT3 SMD
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        47
#       </id>
#       <code>
#        36266S604RO
#       </code>
#       <description>
#        DIODO LED ROSSO SMD 0603 LSQ976
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        48
#       </id>
#       <code>
#        36266S605VE
#       </code>
#       <description>
#        DIODO LED VERDE SMD 0603 LT Q39G
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        49
#       </id>
#       <code>
#        36266S40300
#       </code>
#       <description>
#        DIODO LED RGB 90Â° 3.2X1.5X1H WURTH
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        50
#       </id>
#       <code>
#        36623S40121
#       </code>
#       <description>
#        COND.CER.CHIP 0603  10PF 25V 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        51
#       </id>
#       <code>
#        36623S60131
#       </code>
#       <description>
#        COND.CER.CHIP 0603  1NF 50V X7R 10%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        52
#       </id>
#       <code>
#        36623S80131
#       </code>
#       <description>
#        COND.CER.CHIP 0603 100NF 50V X7R10%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        53
#       </id>
#       <code>
#        36623S90120
#       </code>
#       <description>
#        COND.CER.CHIP 0603  1UF 16V X5R 10%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        54
#       </id>
#       <code>
#        36623S96620
#       </code>
#       <description>
#        COND.CER.CHIP 0603 4.7UF 6V3 XR510%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        55
#       </id>
#       <code>
#        36623SA3420
#       </code>
#       <description>
#        COND.CER.CHIP 22UF6.3V 20% X5R 0603
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        56
#       </id>
#       <code>
#        36850S00011
#       </code>
#       <description>
#        CHIP RES. 0603  0R0 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        57
#       </id>
#       <code>
#        36850S46611
#       </code>
#       <description>
#        CHIP RES. 0603  47R 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        58
#       </id>
#       <code>
#        36850S54211
#       </code>
#       <description>
#        CHIP RES. 0603 270R 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        59
#       </id>
#       <code>
#        36850S55111
#       </code>
#       <description>
#        CHIP RES. 0603 330R 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        60
#       </id>
#       <code>
#        36850S56611
#       </code>
#       <description>
#        CHIP RES. 0603 470R 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        61
#       </id>
#       <code>
#        36850S60911
#       </code>
#       <description>
#        CHIP RES. 0603 1K2 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        62
#       </id>
#       <code>
#        36850S66611
#       </code>
#       <description>
#        CHIP RES. 0603  4K7 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        63
#       </id>
#       <code>
#        36850S70111
#       </code>
#       <description>
#        CHIP RES. 0603  10K 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        64
#       </id>
#       <code>
#        36850S80111
#       </code>
#       <description>
#        CHIP RES. 0603 100K 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        65
#       </id>
#       <code>
#        36850SA0111
#       </code>
#       <description>
#        CHIP RES. 0603  10M 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        66
#       </id>
#       <code>
#        36850S86611
#       </code>
#       <description>
#        CHIP RES. 0603 470K 1/10W 5%
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        67
#       </id>
#       <code>
#        32240SV1200
#       </code>
#       <description>
#        CONN.M.DIR.CS (P.0,80) 12 VIE (2X6)
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        68
#       </id>
#       <code>
#        36266S603BI
#       </code>
#       <description>
#        DIODO LED BIANCO 90Â° 2.9X1.3 SMD
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        69
#       </id>
#       <code>
#        TEST3
#       </code>
#       <description>
#        COMPONENTE DI TEST
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        70
#       </id>
#       <code>
#        093969333
#       </code>
#       <description>
#        TESTE
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        71
#       </id>
#       <code>
#        70-1321-0009
#       </code>
#       <description>
#        BJT SMD NPN  0,1A 50V SOT-723-3
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        72
#       </id>
#       <code>
#        70-1321-0008
#       </code>
#       <description>
#        BJT SMD NPN  0,1A 50V SOT-723-3
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        73
#       </id>
#       <code>
#        70-1321-0006
#       </code>
#       <description>
#        TRANSISTOR SMD
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        74
#       </id>
#       <code>
#        TESTA
#       </code>
#       <description>
#        COMPONENTE DI TEST
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#      <iteminfo>
#       <id>
#        75
#       </id>
#       <code>
#        TEST-A
#       </code>
#       <description>
#        COMPONENTE DI TEST
#       </description>
#       <tech>
#        1
#       </tech>
#       <notes>
#       </notes>
#       <supplier>
#       </supplier>
#       <maxlying>
#        0
#       </maxlying>
#       <refuse>
#        0
#       </refuse>
#       <minsupply>
#        0
#       </minsupply>
#       <defaultquantity>
#        0
#       </defaultquantity>
#       <mslhour>
#        0
#       </mslhour>
#       <partialuse>
#        false
#       </partialuse>
#       <price>
#        0
#       </price>
#       <stockquantity>
#        0
#       </stockquantity>
#       <incomingquantity>
#        0
#       </incomingquantity>
#       <rformat>
#       </rformat>
#       <splicinginfo>
#       </splicinginfo>
#      </iteminfo>
#     </itemlist>
#    </out>
#   </resp>
#  </body>
# </html>

# %%
soup.minsupply.text
# Out:
# '0'

# %%
soup.tech.text
# Out:
# '1'

# %%
soup.reel_id.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e4617b3a6f60> in <module>
# ----> 1 soup.reel_id.text
#
# AttributeError: 'NoneType' object has no attribute 'text'
