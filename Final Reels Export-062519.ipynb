# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pyodbc 
db = pyodbc.connect('Driver={SQL Server};'
                      'Server=PGI-M2M;'
                      'Database=M2MDATA04;'
                      'Trusted_Connection=yes;')
query = 'select fpartno, fpartrev, flot, fonhand, flocation  from dbo.inonhd'
v = pd.read_sql_query(query , db)
v['fpartno'] = v['fpartno'].str.replace(' ', '')
v['flot'] = v['flot'].str.replace(' ', '')
v['fonhand'] = v['fonhand'].replace(' ', '')
v['fpartrev'] = v['fpartrev'].replace(' ', '')
v['flocation'] = v['flocation'].replace(' ', '')

v.replace('', np.nan, inplace=True)
v.applymap(lambda x: x.rstrip() if type(x)==str else x)
v = v[pd.notnull(v['flot'])]
v = v.drop_duplicates('flot',keep = 'first')

v = v[(v[['fonhand']] >= 1).all(axis=1)]
v.to_csv('062419.csv', index = False)

# %%
# Out:
#            fpartno fpartrev           flot  fonhand       flocation
# 9940     100372-LF                     PG1      1.0  SR
# 10155    240476-LF                      13   1000.0  SR
# 10156     42023-LF                      1C    390.0  SR
# 10157     24489-LF           MW62620181130     28.0  SR
# 10158     42343-LF                      1G      2.0  SR
# 10159     42342-LF                      1H      8.0  SR
# 10160     24702-LF           RB62620181159   2570.0  SR
# 10161     24705-LF           RB62620181207   2140.0  SR
# 10162     24706-LF           RB62620181212     27.0  SR
# 10163     24711-LF           RB62620181222     85.0  SR
# 10164     24712-LF             BIN24712-LF     10.0  SR
# 10165     24712-LF           RB62620181225     34.0  SR
# 10166     24714-LF           RB62620181240    283.0  SR
# 10167     24715-LF           RB62620181245     64.0  SR
# 10168     24718-LF           RB62620181315   3943.0  SR
# 10169     42169-LF                      1R    500.0  SR
# 10170     63876-LF                      1U     19.0  SR
# 10171     63877-LF                      1W     10.0  SR
# 10172     90684-LF                      1P    166.0  SR
# 10173     80766-LF                      27   1397.0  SR
# 10174     64078-LF                      28     36.0  SR
# 10175     24720-LF           RB62620181356     37.0  SR
# 10176    330295-LF           RB62620181358    105.0  SR
# 10177    330295-LF           RB62620181359    177.0  SR
# 10178    330295-LF           RB62620181360     50.0  SR
# 10179    330437-LF           RB62620181402    431.0  SR
# 10180    330437-LF           RB62620181403    470.0  SR
# 10181    330447-LF           RB62620181405    880.0  SR
# 10182     42044-LF           RB62620181415    438.0  SR
# 10183     42046-LF           RB62620181418    893.0  SR
# ...            ...      ...            ...      ...             ...
# 25156    100433-LF                     CYJ    250.0  SR
# 25157     24004-LF                     CYK    150.0  SR
# 25158     24005-LF                     CYL    150.0  SR
# 25159     41599-LF                     CYM    225.0  SR
# 25160     41603-LF                     CYN    125.0  SR
# 25161     62822-LF                     CYO    200.0  SR
# 25162     63069-LF                     CYR    110.0  SR
# 25163     63070-LF                     CYP    110.0  SR
# 25164     63071-LF                     CYS    110.0  SR
# 25165     70362-LF                     CYQ    600.0  SR
# 25166     60885-LF                     CYT    196.0  SR
# 25170     63183-LF              VA62119339   1038.0  SR
# 25172  80279-LF-CE              VA62119354   1650.0  SR
# 25173     24635-LF                      8Q   2178.0  SR
# 25174     63921-LF                     CYU   1000.0  SR
# 25176     63920-LF                     CYV    473.0  SR
# 25177     24981-LF                     CYX   5000.0  SR
# 25178     24990-LF                     CYY   5000.0  SR
# 25179    330471-LF                     CYZ   1000.0  SR
# 25180    330474-LF                     CZ1   3000.0  SR
# 25181     24978-LF                     CYW   4000.0  SR
# 25182     24978-LF            JS6241912261   4000.0  SR
# 25183     42105-LF                     CZ3  10000.0  SR
# 25184    330473-LF                     CZ0   1000.0  SR
# 25185     41863-LF                     CZ2    900.0  SR
# 25186     41863-LF            JS6241912291    900.0  SR
# 25188    193162-LF                     CZ4   2000.0  SR
# 25190     63927-LF                     CZ5   2500.0  SR
# 25191     41005-LF                     CZ6    500.0  SR
# 25193    150331-LF                     CZ7   3000.0  SR
#
# [12954 rows x 5 columns]
