# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pyodbc

# %%
db = pyodbc.connect('Driver={SQL Server};'
                      'Server=PGI-M2M;'
                      'Database=M2MDATA25;'
                      'Trusted_Connection=yes;')


df = pd.read_csv('Part Desc 2.csv')

query = 'select fpono, fpartno, fdescript, fvpartno, finvqty from dbo.poitem'

query2 = 'SELECT fpartno, fvpartno from dbo.invend'


query3 = 'SELECT fcpartno, fclot, fnquantity from qalotc'


i = pd.read_sql_query(query , db)
p = pd.read_sql_query(query2 , db)
q = pd.read_sql_query(query3 , db)
p['fvpartno'] = p['fvpartno'].str.replace(' ', '')
p['fpartno'] = p['fpartno'].str.replace(' ', '')



p.applymap(lambda x: x.rstrip() if type(x)==str else x)

p['fvpartno'] = p['fvpartno'].str.strip()
p.replace('', np.nan, inplace=True)
i['fvpartno'] = i['fvpartno'].str.replace(' ', '')
i['fpartno'] = i['fpartno'].str.replace(' ', '')
i['fdescript'] = i['fdescript'].str.replace(' ', '')
i['fpono'] = i['fpono'].str.replace(' ', '')

i.applymap(lambda x: x.rstrip() if type(x)==str else x)

i['fvpartno'] = i['fvpartno'].str.strip()
i.replace('', np.nan, inplace=True)
q['fcpartno'] = q['fcpartno'].str.replace(' ', '')
q['fclot'] = q['fclot'].str.replace(' ', '')
q['fnquantity'] = q['fnquantity'].apply(str).str.replace(' ', '')



p.applymap(lambda x: x.rstrip() if type(x)==str else x)

q['fcpartno'] = q['fcpartno'].str.strip()
q.replace('', np.nan, inplace=True)

# %%
conv = dict(zip(p['fpartno'].values, p['fvpartno'].values))

# %%
i['fvpartno'] = i['fvpartno'].fillna(i['fpartno'].apply(lambda x: conv.get(x)))

# %%
i.drop(['fpono', 'fdescript'], axis=1, inplace=True)

# %%
#i.to_csv('Individual Reel.csv', index = False)

# %%
q
# Out:
#         fcpartno       fclot fnquantity
# 0      390035-LF         PG2     1695.0
# 1      390035-LF         PG2     1695.0
# 2      390035-LF         PG2    -3390.0
# 3       11252-LF      RBC1A1      359.0
# 4       11252-LF      RBC1A1      -64.0
# 5       11252-LF      RBC1A2     5000.0
# 6       11252-LF      RBC1A3     5000.0
# 7       11252-LF      RBC1A1      -40.0
# 8       11378-LF      RBC1A4       11.0
# 9       11378-LF      RBC1A5       39.0
# 10      20003-LF      RBC1A6     3339.0
# 11      20003-LF      RBC1A7     2997.0
# 12      20003-LF      RBC1A7      167.0
# 13      20003-LF      RBC1A7     -167.0
# 14      20003-LF      RBC1A8      167.0
# 15      20003-LF      RBC1A9      127.0
# 16      20003-LF     RBC1A10      219.0
# 17      20003-LF     RBC1A11      228.0
# 18      20003-LF     RBC1A12      155.0
# 19      20003-LF     RBC1A14     5000.0
# 20      20003-LF     RBC1A15     5000.0
# 21      20003-LF     RBC1A16     5000.0
# 22      20003-LF     RBC1A17     5000.0
# 23      20003-LF     RBC1A18      195.0
# 24      20003-LF     RBC1A19     5000.0
# 25      20003-LF     RBC1A20     5000.0
# 26      20003-LF     RBC1A21     5000.0
# 27      20003-LF     RBC1A22     5000.0
# 28      20003-LF     RBC1A23      990.0
# 29      20003-LF     RBC1A24      810.0
# ...          ...         ...        ...
# 81821   62825-LF  VA52194322       18.0
# 81822   62825-LF         9MP       36.0
# 81823   62829-LF   VA5219440       41.0
# 81824   62831-LF   VA5219448       69.0
# 81825   62832-LF   VA5219451       62.0
# 81826   62850-LF         816       -5.0
# 81827   62850-LF   VA5219454       30.0
# 81828   62851-LF         813       -4.0
# 81829   62853-LF         814      -16.0
# 81830   62853-LF         814       -1.0
# 81831   62858-LF  VA52195011       33.0
# 81832   62858-LF  VA52195012      104.0
# 81833   62858-LF   VA5219504        8.0
# 81834   62858-LF   VA5219504       -8.0
# 81835   62860-LF   VA5219504        8.0
# 81836   62861-LF   VA5219528       10.0
# 81837   62870-LF   VA5219531       20.0
# 81838   62873-LF   VA5219533       53.0
# 81839   62877-LF   VA5219536       26.0
# 81840   62878-LF         84I        9.0
# 81841   62878-LF  VA52195381       22.0
# 81842   62878-LF  VA52195382       45.0
# 81843   62879-LF  VA52195421       50.0
# 81844   62879-LF  VA52195422      184.0
# 81845   62879-LF  VA52195423       50.0
# 81846   62879-LF  VA52195423      450.0
# 81847   62881-LF  VA52195461        8.0
# 81848   62881-LF  VA52195462        9.0
# 81849   62884-LF   VA5219549       11.0
# 81850   62885-LF   VA5219551       65.0
#
# [81851 rows x 3 columns]

# %%
parts = df["fpartno"].tolist()

# %%
i = i[i['fpartno'].isin(parts)]

# %%
i.to_csv('Reels.csv', index = False)

# %%
df
# Out:
#                       fpartno                       fdescript frev
# 0                       10551             RES,2.2K,5%,1/8W,CF  NaN
# 1                       10552           RES,220,5%,2W,METALOX  NaN
# 2                       10553  RES,100K,1%,1/8W,MF,DALECMF-55  NaN
# 3                       10554               RES,22,5%,1/8W,CF  NaN
# 4                       10555             RES,5.6K,5%,1/8W,CF  NaN
# 5                       10556              RES,33K,5%,1/8W,CF  NaN
# 6                       30232           CAP,3.3,35V,TANT,.1SP  NaN
# 7                       30233          CAP,3.3,10V,TANT,AXIAL  NaN
# 8                       30234           CAP,3.9,250V,POLY,10%  NaN
# 9                       30235             CAP,30,500V,MICA,5%  NaN
# 10                      30237  CAP,30,1000V,DISC,NPO,5%,.25SP  NaN
# 11                      30238      CAP,33,16V,ALUM.ELEC,AXIAL  NaN
# 12                      50180             IC,SN74LS365,16-DIP  NaN
# 13                      50181                      IC,74LS366  NaN
# 14                      50182             IC,SN74LS367,16-DIP  NaN
# 15                      50183                     IC,74LS373N  NaN
# 16                      50184                     IC,74LS374N  NaN
# 17                      50185             IC,SN74LS377,20-DIP  NaN
# 18                     170140              TB,3POS,PCMNT,.325  NaN
# 19                     170141           TB,15POS,1ROW,.375,PC  NaN
# 20                     170142                 TB,2POS,PC,.375  NaN
# 21                     170143                 TB,3POS,PC,.375  NaN
# 22                     170144           TB,15POS,5.0MMSP,PLUG  NaN
# 23                     170145           TB,20POS,5.0MMSP,PLUG  NaN
# 24                     190939       CONN,NORWESCO,09S,DE9S,9P  NaN
# 25                     190940           CONN,MOLEX,22-55-2061  NaN
# 26                     190941           CONN,MOLEX,22-55-2141  NaN
# 27                     190942           CONN,MOLEX,22-55-2041  NaN
# 28                     190943           CONN,MOLEX,50-57-9002  NaN
# 29                     190944         CONN,3X1HOUSING,WIREMTD  NaN
# ...                       ...                             ...  ...
# 37977                20885-LF        SMRES,8.06K,1%,1/4W,1206  NaN
# 37978                20884-LF        SMRES,5.36K,1%,1/4W,1206  NaN
# 37979                20393-LF          SMRES,249,1%,1/4W,1206  NaN
# 37980                20169-LF         SMRES,61.9,1%,1/4W,1206  NaN
# 37981                20359-LF        SMRES,3.48K,1%,1/4W,1206  NaN
# 37982                20882-LF         SMRES,56.2,1%,1/4W,1206  NaN
# 37983                20092-LF          SMRES,240,5%,1/4W,1206  NaN
# 37984                20236-LF          SMRES,390,5%,1/4W,1206  NaN
# 37985                20178-LF         SMRES,7.5K,1%,1/4W,1206  NaN
# 37986                20065-LF          SMRES,180,5%,1/4W,1206  NaN
# 37987                20078-LF         SMRES,2.7K,5%,1/4W,1206  NaN
# 37988                20058-LF          SMRES,15K,5%,1/4W,1206  NaN
# 37989                20086-LF          SMRES,22K,5%,1/4W,1206  NaN
# 37990                20111-LF         SMRES,3.9K,5%,1/4W,1206  NaN
# 37991                21144-LF           SMRES,1K,5%,1/4W,1206  NaN
# 37992                20264-LF         SMRES,5.1K,5%,1/4W,1206  NaN
# 37993                20106-LF         SMRES,3.3K,5%,1/4W,1206  NaN
# 37994                20355-LF          SMRES,12K,5%,1/4W,1206  NaN
# 37995                40091-LF      SMCAP,470P,NPO,50V,5%,1206  NaN
# 37996    MEZZ_ANSS_0002-LFKIT        PROTOTYPEKIT;JOBI7645HAE    1
# 37997                40082-LF       SMCAP,33P,NPO,5%,50V,1206  NaN
# 37998                40060-LF       SMCAP,18P,50V,NPO,5%,1206  NaN
# 37999                40068-LF       SMCAP,22P,50V,5%,NPO,1206  NaN
# 38000                20891-LF          SMRES,130,1%,1/4W,1206  NaN
# 38001                40067-LF      SMCAP,220P,NPO,50V,5%,1206  NaN
# 38002                40052-LF       SMCAP,10P,NPO,50V,5%,1206  NaN
# 38003                40031-LF        SMCAP,.1,50V,5%,X7R,1206  NaN
# 38004                40046-LF      SMCAP,.01,50V,X7R,10%,1206  NaN
# 38005                40048-LF      SMCAP,100P,NPO,5%,50V,1206  NaN
# 38006  1500-SLS-0031-02-LFKIT           KIT,JOBI7647,DIALIGHT  NaN
#
# [38007 rows x 3 columns]
