# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import pyodbc

# %%
db = pyodbc.connect('Driver={SQL Server};'
                      'Server=PGI-M2M;'
                      'Database=M2MDATA04;'
                      'Trusted_Connection=yes;')

# %%
df = pd.read_csv('Part Desc 2.csv')

# %%
query2 = 'SELECT fpartno, fvpartno from dbo.invend'
query3 = 'SELECT * from qalotc'

# %%
p = pd.read_sql_query(query2 , db)
q = pd.read_sql_query(query3 , db)

# %%
p['fvpartno'] = p['fvpartno'].str.replace(' ', '')
p['fpartno'] = p['fpartno'].str.replace(' ', '')

# %%
p = p.applymap(lambda x: x.rstrip() if type(x)==str else x)

# %%
q = q.applymap(lambda x: x.rstrip() if type(x)==str else x)

# %%
parts = df["fpartno"].tolist()

# %%
q = q[q['fcpartno'].isin(parts)]

# %%
#q = q[q['fnquantity']>=1]

# %%
#q.to_csv('Reels.csv', index = False)

# %%
#q=q.drop_duplicates(keep='first')

# %%
q
# Out:
#       fctype fcdoc   fcpartno fcpartrev            fclot fcuseintype  \
# 0          I        390035-LF                        PG2           I
# 1          I        390035-LF                        PG2           I
# 2          I        390035-LF                        PG2           I
# 3          I         11252-LF                     RBC1A1           I
# 4          I         11252-LF                     RBC1A1           I
# 5          I         11252-LF                     RBC1A2           I
# 6          I         11252-LF                     RBC1A3           I
# 7          I         11252-LF                     RBC1A1           I
# 8          I         11378-LF                     RBC1A4           I
# 9          I         11378-LF                     RBC1A5           I
# 10         I         20003-LF                     RBC1A6           I
# 11         I         20003-LF                     RBC1A7           I
# 12         I         20003-LF                     RBC1A7           I
# ...

# %%
#q.to_csv('Reels.csv', index = False)

# %%
q.to_csv('Reels.csv', index = False)
